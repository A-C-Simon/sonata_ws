# %%
# run before: aws configure

# %%
# !aws s3 ls s3://3d-scenes \
  --endpoint-url https://storage.yandexcloud.net
# Out:
#                            PRE raw/
# 2026-03-03 20:11:48        773 app.js
# 2026-03-03 20:11:48        915 index.html

# %%
# !aws s3 ls s3://3d-scenes/raw/semantic_kitti/sequences/ \
  --endpoint-url https://storage.yandexcloud.net
# Out:
#                            PRE 00/
#                            PRE 01/
#                            PRE 02/
#                            PRE 03/
#                            PRE 04/
